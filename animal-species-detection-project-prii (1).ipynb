# %% [markdown]
# ## Task 1: Importing Libraries

# %%
import keras
import os
import shutil
import numpy as np
import math
import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from platform import python_version

print('Python version:', python_version())
print('Numpy version:', np.__version__)
print('Seaborn version:', sns.__version__)
from distutils.dir_util import copy_tree
import tensorflow as tf
print('tensorflow version: ',tf.__version__)
print('keras version:', keras.__version__)
# Out:
# Python version: 3.7.6
# Numpy version: 1.18.5
# Seaborn version: 0.10.0
# tensorflow version:  2.3.1
# keras version: 2.4.3

# %%
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.models import Sequential
from keras.layers import Dropout
from keras_preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Task 2: Dataset Creation

# %%
#created data set using console
source='../input/african-wildlife/'
target='./train_data/'
shutil.copytree(source, target)
os.mkdir('test_data')

# %%
# remove unwanted data and create same classed for test_data

path="./train_data/"
for file in os.listdir(path):
    for image in os.listdir(path+file+'/'):
        if '.jpg' not in image:
            os.remove(path+file+'/'+image)
    os.mkdir('./test_data/'+file)

# %%
# create test_data by taking 25% images from data

total_train_images,total_test_images,total_train_classes,total_test_classes=0,0,0,0
path="./train_data/"
for file in os.listdir(path):
    total_train_classes+=1
    total_images=len(os.listdir(path+file+"/"))
    test_image_count=(25/100)*total_images #25% for test and 75% for train
    for i in range(math.ceil(test_image_count)):
        img=random.choice(os.listdir(path+file+'/'))
        shutil.move(path+file+'/'+img,'./test_data/'+file+'/')
        #print(img)
    print(file,total_images,math.ceil(test_image_count))
    total_train_images+=(total_images-math.ceil(test_image_count))
    #print(file,math.ceil(test_image_count))
print("total train images are : ",total_train_images," and total train classes are : ",total_train_classes)
# Out:
# rhino 375 94
# zebra 376 94
# elephant 375 94
# buffalo 375 94
# total train images are :  1125  and total train classes are :  4

# %% [markdown]
# ## Task 3: Model Creation

# %%
model = Sequential()

# %%
#inputlayer : apply filters
model.add(Convolution2D(filters=32, 
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same',
                        activation='relu',
                   input_shape=(32, 32, 1)))

# %%
# pooling layer where we are doing maxpooling
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#adding one more convolution layer for better model
model.add(Convolution2D(filters=32, 
                        kernel_size=(3,3),
                        strides=(1,1),
                        padding='same', 
                        activation='relu'
                      ))

# %%
#adding one more Pooling layer for better model
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#dropout regularlization
model.add(Dropout(0.5))

# %%
#layer in which we are converting 2d/3d image to 1d image i.e flattening
model.add(Flatten())

# %%
# layer: appling relu to give positive output from here our hidden layerrs starts
model.add(Dense(units=20, activation='relu'))

# %%
#dropout regularlization
model.add(Dropout(0.5))

# %%
# output layer : Since we have to do multi-class classification so we'll apply softmax activation function 
# we have 4 classes of animals so output layer would have that many neurons.
model.add(Dense(units=4, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 20)                40980
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 84
# =================================================================
# Total params: 50,632
# Trainable params: 50,632
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Task 4: Image Augmentation

# %%
#url : https://keras.io/api/preprocessing/image/ 
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)
training_set = train_datagen.flow_from_directory(
        './train_data/',
        target_size=(32,32),
        color_mode="grayscale",
        batch_size=64,
        class_mode='categorical')
test_set = test_datagen.flow_from_directory(
        './test_data/',
        target_size=(32,32),
        color_mode="grayscale",
        batch_size=64,
        class_mode='categorical')
# Out:
# Found 1125 images belonging to 4 classes.
# Found 376 images belonging to 4 classes.

# %%
training_set.class_indices # to see classes of our dataset
# Out:
# {'buffalo': 0, 'elephant': 1, 'rhino': 2, 'zebra': 3}

# %% [markdown]
# ## Task 5: Model Training

# %%
history = model.fit(
        training_set,
        steps_per_epoch=(1125/64),
        epochs=100,
        validation_data=test_set,
        validation_steps=(376/64))
# Out:
# Epoch 1/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.9269 - accuracy: 0.5956 - val_loss: 1.0189 - val_accuracy: 0.6064
# Epoch 2/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.9171 - accuracy: 0.5876 - val_loss: 0.9359 - val_accuracy: 0.6223
# Epoch 3/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.9012 - accuracy: 0.6098 - val_loss: 0.9635 - val_accuracy: 0.6250
# Epoch 4/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8760 - accuracy: 0.6293 - val_loss: 1.0889 - val_accuracy: 0.5878
# Epoch 5/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.9018 - accuracy: 0.6151 - val_loss: 0.9276 - val_accuracy: 0.6277
# Epoch 6/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8997 - accuracy: 0.6133 - val_loss: 0.9796 - val_accuracy: 0.6170
# Epoch 7/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.9298 - accuracy: 0.5831 - val_loss: 1.0702 - val_accuracy: 0.5771
# Epoch 8/100
# 18/17 [==============================] - 25s 1s/step - loss: 0.9104 - accuracy: 0.5716 - val_loss: 1.0495 - val_accuracy: 0.5904
# Epoch 9/100
# 18/17 [==============================] - 25s 1s/step - loss: 0.9162 - accuracy: 0.6089 - val_loss: 0.9080 - val_accuracy: 0.6170
# Epoch 10/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8971 - accuracy: 0.5982 - val_loss: 0.9474 - val_accuracy: 0.6223
# Epoch 11/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8728 - accuracy: 0.6267 - val_loss: 0.8909 - val_accuracy: 0.6410
# Epoch 12/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.9121 - accuracy: 0.5938 - val_loss: 0.8296 - val_accuracy: 0.6436
# Epoch 13/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8998 - accuracy: 0.6178 - val_loss: 0.8989 - val_accuracy: 0.6197
# Epoch 14/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8728 - accuracy: 0.6320 - val_loss: 0.9371 - val_accuracy: 0.6144
# Epoch 15/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8888 - accuracy: 0.6036 - val_loss: 0.8963 - val_accuracy: 0.6090
# Epoch 16/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8593 - accuracy: 0.6187 - val_loss: 1.0410 - val_accuracy: 0.5878
# Epoch 17/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8941 - accuracy: 0.6249 - val_loss: 0.9875 - val_accuracy: 0.5984
# Epoch 18/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8886 - accuracy: 0.5982 - val_loss: 1.0201 - val_accuracy: 0.6037
# Epoch 19/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8630 - accuracy: 0.6311 - val_loss: 0.9172 - val_accuracy: 0.6250
# Epoch 20/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8532 - accuracy: 0.6151 - val_loss: 0.9310 - val_accuracy: 0.6277
# Epoch 21/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8864 - accuracy: 0.6187 - val_loss: 0.9435 - val_accuracy: 0.6223
# Epoch 22/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8744 - accuracy: 0.6124 - val_loss: 1.0392 - val_accuracy: 0.6064
# Epoch 23/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.8915 - accuracy: 0.6151 - val_loss: 0.9082 - val_accuracy: 0.6383
# Epoch 24/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8609 - accuracy: 0.6364 - val_loss: 1.0835 - val_accuracy: 0.5984
# Epoch 25/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8610 - accuracy: 0.6222 - val_loss: 1.0022 - val_accuracy: 0.5957
# Epoch 26/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8859 - accuracy: 0.6080 - val_loss: 0.8397 - val_accuracy: 0.6622
# Epoch 27/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8774 - accuracy: 0.6142 - val_loss: 0.9837 - val_accuracy: 0.6197
# Epoch 28/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8560 - accuracy: 0.6329 - val_loss: 1.0054 - val_accuracy: 0.6117
# Epoch 29/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8636 - accuracy: 0.6276 - val_loss: 1.1147 - val_accuracy: 0.5957
# Epoch 30/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.8434 - accuracy: 0.6329 - val_loss: 0.9562 - val_accuracy: 0.6277
# Epoch 31/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8406 - accuracy: 0.6409 - val_loss: 0.9649 - val_accuracy: 0.6170
# Epoch 32/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8393 - accuracy: 0.6311 - val_loss: 0.9125 - val_accuracy: 0.6410
# Epoch 33/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8911 - accuracy: 0.6124 - val_loss: 0.9456 - val_accuracy: 0.6197
# Epoch 34/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8665 - accuracy: 0.6169 - val_loss: 0.8887 - val_accuracy: 0.6383
# Epoch 35/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8552 - accuracy: 0.6329 - val_loss: 0.9072 - val_accuracy: 0.6250
# Epoch 36/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8714 - accuracy: 0.6187 - val_loss: 1.0396 - val_accuracy: 0.6117
# Epoch 37/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8606 - accuracy: 0.6178 - val_loss: 1.0180 - val_accuracy: 0.6197
# Epoch 38/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8463 - accuracy: 0.6409 - val_loss: 0.8693 - val_accuracy: 0.6356
# Epoch 39/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8598 - accuracy: 0.6311 - val_loss: 0.8108 - val_accuracy: 0.6622
# Epoch 40/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8557 - accuracy: 0.6284 - val_loss: 0.8458 - val_accuracy: 0.6543
# Epoch 41/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8692 - accuracy: 0.6231 - val_loss: 0.9099 - val_accuracy: 0.6383
# Epoch 42/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8751 - accuracy: 0.6293 - val_loss: 0.8521 - val_accuracy: 0.6489
# Epoch 43/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8529 - accuracy: 0.6569 - val_loss: 0.9095 - val_accuracy: 0.6303
# Epoch 44/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8457 - accuracy: 0.6231 - val_loss: 1.0136 - val_accuracy: 0.6277
# Epoch 45/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8419 - accuracy: 0.6382 - val_loss: 0.9701 - val_accuracy: 0.6197
# Epoch 46/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8481 - accuracy: 0.6400 - val_loss: 0.9425 - val_accuracy: 0.6356
# Epoch 47/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8513 - accuracy: 0.6320 - val_loss: 1.0679 - val_accuracy: 0.6011
# Epoch 48/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8113 - accuracy: 0.6596 - val_loss: 1.2324 - val_accuracy: 0.5638
# Epoch 49/100
# 18/17 [==============================] - 25s 1s/step - loss: 0.8373 - accuracy: 0.6418 - val_loss: 1.0247 - val_accuracy: 0.6144
# Epoch 50/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8498 - accuracy: 0.6071 - val_loss: 1.0903 - val_accuracy: 0.5984
# Epoch 51/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8652 - accuracy: 0.6516 - val_loss: 0.9751 - val_accuracy: 0.6117
# Epoch 52/100
# 18/17 [==============================] - 25s 1s/step - loss: 0.8452 - accuracy: 0.6311 - val_loss: 0.8880 - val_accuracy: 0.6383
# Epoch 53/100
# 18/17 [==============================] - 25s 1s/step - loss: 0.8428 - accuracy: 0.6356 - val_loss: 0.9847 - val_accuracy: 0.6090
# Epoch 54/100
# 18/17 [==============================] - 25s 1s/step - loss: 0.8759 - accuracy: 0.6204 - val_loss: 0.8863 - val_accuracy: 0.6330
# Epoch 55/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8292 - accuracy: 0.6480 - val_loss: 0.9644 - val_accuracy: 0.6250
# Epoch 56/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8411 - accuracy: 0.6249 - val_loss: 0.9565 - val_accuracy: 0.6117
# Epoch 57/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8297 - accuracy: 0.6302 - val_loss: 0.9341 - val_accuracy: 0.6197
# Epoch 58/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8152 - accuracy: 0.6542 - val_loss: 1.0338 - val_accuracy: 0.5984
# Epoch 59/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7976 - accuracy: 0.6418 - val_loss: 0.9925 - val_accuracy: 0.6250
# Epoch 60/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8433 - accuracy: 0.6347 - val_loss: 0.8304 - val_accuracy: 0.6702
# Epoch 61/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8148 - accuracy: 0.6427 - val_loss: 0.9147 - val_accuracy: 0.6303
# Epoch 62/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8082 - accuracy: 0.6293 - val_loss: 0.9126 - val_accuracy: 0.6383
# Epoch 63/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8110 - accuracy: 0.6560 - val_loss: 1.0049 - val_accuracy: 0.6303
# Epoch 64/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8014 - accuracy: 0.6471 - val_loss: 1.0877 - val_accuracy: 0.6117
# Epoch 65/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8159 - accuracy: 0.6524 - val_loss: 1.0027 - val_accuracy: 0.6223
# Epoch 66/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8247 - accuracy: 0.6276 - val_loss: 1.2050 - val_accuracy: 0.5957
# Epoch 67/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.8197 - accuracy: 0.6320 - val_loss: 0.9244 - val_accuracy: 0.6303
# Epoch 68/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8120 - accuracy: 0.6391 - val_loss: 0.9111 - val_accuracy: 0.6303
# Epoch 69/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7949 - accuracy: 0.6684 - val_loss: 0.8431 - val_accuracy: 0.6489
# Epoch 70/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8231 - accuracy: 0.6533 - val_loss: 0.9524 - val_accuracy: 0.6170
# Epoch 71/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7972 - accuracy: 0.6462 - val_loss: 1.2248 - val_accuracy: 0.5798
# Epoch 72/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7978 - accuracy: 0.6587 - val_loss: 1.1250 - val_accuracy: 0.6011
# Epoch 73/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7916 - accuracy: 0.6516 - val_loss: 1.0587 - val_accuracy: 0.6144
# Epoch 74/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.8027 - accuracy: 0.6667 - val_loss: 0.9231 - val_accuracy: 0.6303
# Epoch 75/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8217 - accuracy: 0.6471 - val_loss: 0.9509 - val_accuracy: 0.6144
# Epoch 76/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7962 - accuracy: 0.6480 - val_loss: 0.9574 - val_accuracy: 0.6303
# Epoch 77/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8220 - accuracy: 0.6560 - val_loss: 0.8204 - val_accuracy: 0.6729
# Epoch 78/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8513 - accuracy: 0.6391 - val_loss: 0.8780 - val_accuracy: 0.6277
# Epoch 79/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8086 - accuracy: 0.6293 - val_loss: 0.9045 - val_accuracy: 0.6277
# Epoch 80/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8147 - accuracy: 0.6551 - val_loss: 1.1360 - val_accuracy: 0.6037
# Epoch 81/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8433 - accuracy: 0.6400 - val_loss: 1.1493 - val_accuracy: 0.6011
# Epoch 82/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.8037 - accuracy: 0.6533 - val_loss: 0.9656 - val_accuracy: 0.6250
# Epoch 83/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7991 - accuracy: 0.6569 - val_loss: 1.2918 - val_accuracy: 0.5745
# Epoch 84/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7982 - accuracy: 0.6489 - val_loss: 1.0171 - val_accuracy: 0.6117
# Epoch 85/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7691 - accuracy: 0.6747 - val_loss: 0.8688 - val_accuracy: 0.6489
# Epoch 86/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8012 - accuracy: 0.6249 - val_loss: 1.0062 - val_accuracy: 0.6170
# Epoch 87/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8155 - accuracy: 0.6418 - val_loss: 1.1963 - val_accuracy: 0.5798
# Epoch 88/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8059 - accuracy: 0.6436 - val_loss: 1.3335 - val_accuracy: 0.5585
# Epoch 89/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.7971 - accuracy: 0.6711 - val_loss: 0.9229 - val_accuracy: 0.6250
# Epoch 90/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7735 - accuracy: 0.6631 - val_loss: 1.0519 - val_accuracy: 0.6170
# Epoch 91/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8065 - accuracy: 0.6533 - val_loss: 1.0874 - val_accuracy: 0.5931
# Epoch 92/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8320 - accuracy: 0.6356 - val_loss: 0.9781 - val_accuracy: 0.6197
# Epoch 93/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7638 - accuracy: 0.6498 - val_loss: 0.9698 - val_accuracy: 0.6117
# Epoch 94/100
# 18/17 [==============================] - 27s 1s/step - loss: 0.7570 - accuracy: 0.6542 - val_loss: 0.8923 - val_accuracy: 0.6410
# Epoch 95/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7952 - accuracy: 0.6613 - val_loss: 1.0579 - val_accuracy: 0.6090
# Epoch 96/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7916 - accuracy: 0.6738 - val_loss: 1.0164 - val_accuracy: 0.6250
# Epoch 97/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8035 - accuracy: 0.6498 - val_loss: 1.3060 - val_accuracy: 0.5638
# Epoch 98/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8056 - accuracy: 0.6436 - val_loss: 1.1853 - val_accuracy: 0.5505
# Epoch 99/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.8620 - accuracy: 0.6116 - val_loss: 1.0533 - val_accuracy: 0.6011
# Epoch 100/100
# 18/17 [==============================] - 26s 1s/step - loss: 0.7683 - accuracy: 0.6587 - val_loss: 0.9608 - val_accuracy: 0.6170

# %% [markdown]
# ## Task 6: Accuracy

# %%
#Graphing our training and validation
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'r', label='Training acc')
plt.plot(epochs, val_accuracy, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy') 
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss') 
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
#model.save("simple_animal_classification_model.h5")#save model

# %%
#from keras.models import load_model
#model=load_model("simple_animal_classification_model.h5")

# %% [markdown]
# ## Task 7: Testing

# %%
from keras.preprocessing import image
test_image = image.load_img("../input/african-wildlife/zebra/005.jpg",target_size=(32,32),color_mode='grayscale')
test_image
# Out:
# <PIL.Image.Image image mode=L size=32x32 at 0x79190803F790>

# %%
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)

# %%
result = model.predict(test_image)

my_dict=training_set.class_indices
def get_key(val): 
    for key, value in my_dict.items(): 
         if val == value: 
             return key 
  
    return "key doesn't exist"

pred=list(result[0])
for i in range(len(pred)):
    if pred[i]!=0:
        print(get_key(i))
# Out:
# zebra
